# %% [markdown]
# # Transformer From Scratch – Overview
#
# ## Purpose
# Build a Transformer from first principles in a series of notebooks.
# Focus on understanding every component.
#
# ## What we will implement
# 1. Embeddings
# 2. Positional Encoding
# 3. Scaled Dot-Product Attention
# 4. Multi-Head Attention
# 5. Feed-Forward Network
# 6. Encoder/Decoder Block
# 7. Full Transformer Model
# 8. Training loop on toy data
#
# ## Tools
# - Python 3
# - NumPy only
# - Jupyter Notebook
#
# ## Methodology
# - Forward pass first
# - Understand shapes and math
# - Add backward pass later if desired
# - Test with small examples
